# %%
import db_pack.alpaca.alpaca_daily as alpaca_daily

# %%
alpaca_daily.main()
# Out:
# 0:00:00.000024
#    last_date  symbol_id ticker
# 0 2015-12-30        282     FB
# 1 2015-12-30       2033    LKQ
# 2 2015-12-30       2146   MDLZ
# 3 2015-12-30       2215   MNST
# 4 2015-12-30       2293   NAVI
# 5 2015-12-30       3220   TRIP
# FB
# DATE_DIFF= 2
# FB complete!
# LKQ
# DATE_DIFF= 2
# LKQ complete!
# MDLZ
# DATE_DIFF= 2
# MDLZ complete!
# MNST
# DATE_DIFF= 2
# MNST complete!
# NAVI
# DATE_DIFF= 2
# NAVI complete!
# TRIP
# DATE_DIFF= 2
# TRIP complete!
# 0:00:05.384675

# %%
import db_pack.alpaca.alpaca_symbol_loader as alpaca_symbol_loader

# %%
alpaca_symbol_loader.main()

# %%
import alpaca_trade_api as tradeapi
import configparser

import pandas as pd
import json
import datetime
import q_credentials.db_secmaster_cloud_cred as db_secmaster_cred
import q_credentials.alpaca_cred as alpaca_cred

# %%
api_key=alpaca_cred.api_key
secret_key=alpaca_cred.secret_key
api = tradeapi.REST(api_key, secret_key)
active_assets = api.list_assets(status='active')

# %%
pd.DataFrame(active_assets.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8b97d4d18520> in <module>
# ----> 1 pd.DataFrame(active_assets.values)
#
# AttributeError: 'list' object has no attribute 'values'

# %%
symbols = []
data_vendor_id='alpaca'
now = datetime.datetime.utcnow()
for symbol in active_assets:
    symbols.append({'ticker':symbol.symbol,'exchange':symbol.exchange,'instrument':'us_equity','name':symbol.name,'data_vendor_id':data_vendor_id,'currency':'USD','shortable':symbol.shortable,'easy_to_borrow':symbol.easy_to_borrow,'marginable':symbol.marginable,'tradable':symbol.tradable,'created_date':now,'last_updated_date':now})
#                     ticker,instrument,name,currency,shortable,easy_to_borrow,marginable,tradable,status,exchange_id,data_vendor_id,created_date, last_updated_date
#     symbols.append((symbol.symbol,'us_equity',symbol.name,'USD',symbol.shortable,symbol.easy_to_borrow,symbol.marginable,symbol.tradable,symbol.status,exchange_id,data_vendor_id,now,now))
# write_db.write_db_dataframe(df=pd.DataFrame(symbols), conn=conn, table='symbol') 
print("number of symbols loaded = ",len(symbols))
# Out:
# number of symbols loaded =  8778

# %%
pd.DataFrame(symbols)
# Out:
#      ticker exchange instrument  \
# 0      RTLR   NASDAQ  us_equity
# 1       WES     NYSE  us_equity
# 2      MTDR     NYSE  us_equity
# 3       CWH     NYSE  us_equity
# 4       OVV     NYSE  us_equity
# ...     ...      ...        ...
# 8773   IEUR     ARCA  us_equity
# 8774  KBLMR   NASDAQ  us_equity
# 8775   NVRO     NYSE  us_equity
# 8776  FATBP   NASDAQ  us_equity
# 8777    KEY     NYSE  us_equity
#
#                                                    name data_vendor_id  \
# 0                     Rattler Midstream LP Common Units         alpaca
# 1                        Western Midstream Partners, LP         alpaca
# 2                             MATADOR RESOURCES COMPANY         alpaca
# 3                          Camping World Holdings, Inc.         alpaca
# 4                                          Ovintiv Inc.         alpaca
# ...                                                 ...            ...
# 8773                       iShares Core MSCI Europe ETF         alpaca
# 8774      KBL Merger Corp. IV Rights expiring 11/9/2020         alpaca
# 8775                                        NEVRO CORP.         alpaca
# 8776  FAT Brands Inc. 8.25% Series B Cumulative Pref...         alpaca
# 8777                                            KeyCorp         alpaca
#
#      currency  shortable  easy_to_borrow  marginable  tradable  \
# 0         USD       True            True        True      True
# 1         USD       True            True        True      True
# 2         USD       True            True        True      True
# 3         USD       True            True        True      True
# 4         USD       True            True        True      True
# ...       ...        ...             ...         ...       ...
# 8773      USD       True            True        True      True
# 8774      USD      False           False        True      True
# 8775      USD       True            True        True      True
# 8776      USD      False           False        True      True
# 8777      USD       True            True        True      True
#
#                    created_date          last_updated_date
# 0    2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
# 1    2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
# 2    2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
# 3    2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
# 4    2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
# ...                         ...                        ...
# 8773 2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
# 8774 2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
# 8775 2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
# 8776 2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
# 8777 2020-09-05 23:17:19.975958 2020-09-05 23:17:19.975958
#
# [8778 rows x 12 columns]

# %%
active_assets
# Out:
# [Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '5d9adc41-d4a0-4bed-8e18-a23631528998',
#      'marginable': True,
#      'name': 'Rattler Midstream LP Common Units',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'RTLR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '64b1ce67-9c84-4a31-babf-cf27c1d88829',
#      'marginable': True,
#      'name': 'Western Midstream Partners, LP',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'WES',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '2f00ea44-09ec-47cf-8bd5-63db689b8a88',
#      'marginable': True,
#      'name': 'MATADOR RESOURCES COMPANY',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MTDR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '687edcf2-df9d-4ae2-ba5b-670c914d2541',
#      'marginable': True,
#      'name': 'Camping World Holdings, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CWH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '6a8e775c-1cf3-48bf-a3d1-3ceabcbf0a44',
#      'marginable': True,
#      'name': 'Ovintiv Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'OVV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b7c91d5a-cf61-4cca-ba92-596c4b4bb6dc',
#      'marginable': True,
#      'name': 'Antero Midstream Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '5f6df775-b148-4a42-8dd3-3bb341af3413',
#      'marginable': True,
#      'name': 'ENLINK MIDSTREAM, LLC',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ENLC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '29d5331f-51de-45dc-a429-c0d3d62cb6a9',
#      'marginable': True,
#      'name': 'Tupperware Brands Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TUP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '26f508e4-cedb-4b65-bc98-d1fd46e18f20',
#      'marginable': True,
#      'name': 'Helix Energy Solutions Group, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HLX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '8b38e07c-1b9e-49f7-a4e7-aa597b799146',
#      'marginable': True,
#      'name': 'eXp World Holdings, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'EXPI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '89250558-f610-43ad-984d-bf8e8543f6a4',
#      'marginable': True,
#      'name': 'ADT Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ADT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '34ed070f-b027-4163-9fd8-68cf19df451b',
#      'marginable': True,
#      'name': 'Aercap Holdings N.V.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AER',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '9c592f55-a9a2-4047-a62d-ac7d5abce93b',
#      'marginable': True,
#      'name': 'Cedar Realty Trust, Inc',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CDR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f6e44483-7b85-4100-abfb-c3f08659646b',
#      'marginable': True,
#      'name': 'Seacor Holdings Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CKH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '58173a3c-c7e1-4150-b48f-1af063a88e26',
#      'marginable': True,
#      'name': 'Capital One Financial',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'COF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '9c4269ea-2a6e-4283-b397-aa1f5190ae6a',
#      'marginable': True,
#      'name': 'Dillards Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DDS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '87e3cab4-2c4f-41ed-854c-59f61137af40',
#      'marginable': True,
#      'name': 'WisdomTree International MidCap Dividend Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DIM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '812453a9-6ec4-4edb-a1d6-7f08a987ba23',
#      'marginable': True,
#      'name': 'Emerson Electric Co.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'EMR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '6c324990-c1e8-4b2d-b92e-74f6f778fe54',
#      'marginable': True,
#      'name': 'iShares MSCI Sweden ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'EWD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7f9bc611-ddaf-42bf-9faa-48f007b275c8',
#      'marginable': True,
#      'name': 'Fox Corporation Class B Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'FOX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '618a7eff-7dc3-49cb-af24-6fcdf90dd1d7',
#      'marginable': True,
#      'name': 'frontdoor, inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'FTDR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '1e636ad6-e4f2-4382-81f9-9f0b9303eb29',
#      'marginable': True,
#      'name': 'GENPACT LIMITED',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'G',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'bf744115-9267-41f5-9ae6-4c18f8d149e4',
#      'marginable': True,
#      'name': 'Guess?, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'GES',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '14a06c29-cc38-444d-ab21-90198dc0fa18',
#      'marginable': True,
#      'name': 'Halliburton Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HAL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'c989aafd-f5d1-4239-aefc-d431a8edc3e9',
#      'marginable': True,
#      'name': 'Helmerich & Payne, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '4e590014-273c-474f-940f-6af4a6d36f66',
#      'marginable': True,
#      'name': 'John Bean Technologies Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'JBT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'c29be0fc-a7a5-463f-b5cc-fe31ede2f86f',
#      'marginable': True,
#      'name': 'Nordstrom, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'JWN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '94a74e94-f4f3-42b4-999a-2eebe67d99d3',
#      'marginable': True,
#      'name': 'LAIX Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'LAIX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'aac2723c-d566-4454-965f-5a3373ae1155',
#      'marginable': True,
#      'name': 'Lannett Company, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'LCI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '0d82e509-9040-4a32-9190-43b53b8f0c39',
#      'marginable': True,
#      'name': 'Innovator Nasdaq-100 Power Buffer ETF - April',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NAPR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'db00f7c3-19bb-42b6-9beb-79e92487f99e',
#      'marginable': True,
#      'name': 'Nike, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'NKE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '7f1498a3-85cf-4fa0-a46b-05c9b82b74e4',
#      'marginable': True,
#      'name': 'PAR Technology Corp.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PAR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '579a5c17-051e-4eaa-9f1e-8135f8ad66d2',
#      'marginable': True,
#      'name': 'Permian Basin Royalty Trust',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PBT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '5df9640c-c98a-4bd8-b5c5-2f2afc8a8a26',
#      'marginable': True,
#      'name': 'Public Storage',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PSA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b8ecf383-5df1-4026-a111-3f987c24b9da',
#      'marginable': True,
#      'name': 'Parsons Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PSN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3439d218-ba95-44b0-8996-e7704d0a7f0e',
#      'marginable': True,
#      'name': 'Qumu Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'QUMU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '8b7d2af4-3d0c-43d5-bc55-8709225ff693',
#      'marginable': True,
#      'name': 'Resolute Forest Products Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'RFP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'e93ef48a-f9b8-49f5-9f20-012879a6b598',
#      'marginable': True,
#      'name': 'ProShares UltraShort Utilities',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SDP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '7a129f9c-8d25-4fde-89f5-90630b3ba52b',
#      'marginable': True,
#      'name': 'SiteOne Landscape Supply, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SITE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '069e4d15-1e32-4527-ac58-20f0008f1b15',
#      'marginable': True,
#      'name': 'The Southern Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SOLN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '86cc448e-bb2f-41f0-8780-93b508e118ac',
#      'marginable': True,
#      'name': 'SP Funds S&P 500 Sharia  ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPUS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b8af6911-613b-4c40-9929-ac7939a33959',
#      'marginable': True,
#      'name': 'STAG INDUSTRIAL, INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'STAG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'c9f3086b-659f-4f27-a3b9-66b665bb0117',
#      'marginable': True,
#      'name': 'Systemax Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SYX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'c30bbc9b-379d-4305-96b7-191d084505b6',
#      'marginable': True,
#      'name': 'Titan Machinery Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TITN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'a459db1c-e70f-4c9b-8913-b56406e252fd',
#      'marginable': True,
#      'name': 'TransEnterix Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TRXC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3517112f-c121-4312-8da3-f1d99cca74ba',
#      'marginable': True,
#      'name': 'Tivity Health, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TVTY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '6504b97c-ce65-418d-a704-dddc8ba1d0df',
#      'marginable': True,
#      'name': 'Wipro Limited',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'WIT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '8d59a75e-0afa-410a-a3e1-3766433e38e2',
#      'marginable': True,
#      'name': 'Sundance Energy Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNDE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '30bce310-d492-46a2-a505-649826d5c268',
#      'marginable': True,
#      'name': 'Syndax Pharmaceuticals, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNDX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c865ad10-1aca-4192-ae31-4d385a2fbca7',
#      'marginable': True,
#      'name': 'SenesTech, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNES',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '41de907b-4da8-40c8-baae-d89d0f1f9e12',
#      'marginable': True,
#      'name': 'Security National Financial Corporation Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNFCA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '52e782b3-4876-40e3-819f-7445c4eafefc',
#      'marginable': True,
#      'name': 'Highland/iBoxx Senior Loan ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNLN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'd84edb9e-73c1-4ec1-a9c0-0e849aafb505',
#      'marginable': True,
#      'name': 'Zomedica Pharmaceuticals Corp.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ZOM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '696de543-0cac-4e22-9e43-10c54b32ae6b',
#      'marginable': True,
#      'name': 'Sundial Growers Inc. Common Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNDL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '93431c86-d1e1-4aa2-a21a-e4116e2ce8be',
#      'marginable': True,
#      'name': 'Sony Corporation ADS',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '57eb42c4-4b10-4ca6-a978-b12ce560480e',
#      'marginable': True,
#      'name': 'StoneX Group Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNEX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '0ca6bfdd-7879-464d-a74e-0f07dc3e7d66',
#      'marginable': True,
#      'name': 'Soligenix, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNGX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'ed5bd32c-e72c-4955-a8ca-fd810be824c1',
#      'marginable': True,
#      'name': 'Sanchez Midstream Partners LP',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNMP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd0cad47d-0cef-41b2-8e2e-00fcf06ecf09',
#      'marginable': True,
#      'name': 'CHINA PETROLEUM & CHEMICAL CORPORATION ADS (REP 100 ORDINARY H '
#              'SHARES)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'fa8500c0-9022-4a74-97f9-93d41ed28dac',
#      'marginable': True,
#      'name': 'Synopsys, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNPS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '25633e47-db0a-4840-9c83-147a9c60df10',
#      'marginable': True,
#      'name': 'Global X Funds Global X Internet of Things ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNSR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '8712a04a-1e69-48e0-9640-f0d59a0583c9',
#      'marginable': True,
#      'name': 'Synovus Financial Corp.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '65c08540-d3a8-43cd-8fe3-8d82c1749740',
#      'marginable': True,
#      'name': 'Synovus Financial Corp. 5.875% Fixed-Rate Reset Non-Cumulative '
#              'Perpetual Preferred Stock, Series E',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNV-E',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '5a71649b-e578-4229-81a3-d3a5c1351dd7',
#      'marginable': True,
#      'name': 'The Southern Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '83ad8b5b-51c1-41f4-bf16-cb53e7a9753c',
#      'marginable': True,
#      'name': 'Sustainable Opportunities Acquisition Corp. Units, each '
#              'consisting of one Class A ordinary share and',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOAC.U',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '03f433e8-3a2e-499a-b0d7-117b73ffce67',
#      'marginable': True,
#      'name': 'Sotherly Hotels Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SOHO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '20e6ff1d-897f-4bc3-afdc-a67fb96975a3',
#      'marginable': True,
#      'name': 'Sotherly Hotels Inc. 8.25% Series D Cumulative Redeemable '
#              'Perpetual Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOHON',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'fcfe4b2f-8660-4537-ab01-3a34f07c36c0',
#      'marginable': True,
#      'name': 'Sohu.com Limited American Depositary Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SOHU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '2c38b18a-629e-4804-9b01-4bbe22397d35',
#      'marginable': True,
#      'name': 'The Southern Company  Series 2015A 6.25% Junior Subordinated '
#              'Notes due October 15, 2075',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOJA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '117d8aaa-dcaf-4cc5-87f3-591848530b38',
#      'marginable': True,
#      'name': 'The Southern Company Series 2017B 5.25% Junior Subordinated Notes '
#              'due December 1, 2077',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOJC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b629c678-09ec-4f12-8499-29cbe9ce41c0',
#      'marginable': True,
#      'name': 'ReneSola Ltd American Depositary (Each representing ten shares)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SOL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '760f2420-e170-459e-b410-95451e9c405f',
#      'marginable': True,
#      'name': 'Electrameccanica Vehicles Corp. Ltd. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOLO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'bf53ad58-b0f6-452d-916f-ce8b19d67216',
#      'marginable': True,
#      'name': 'Sonoco Products Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SON',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'b88a5b4a-2d4d-48c0-8cfb-a7d91a4d3290',
#      'marginable': True,
#      'name': 'Sonim Technologies, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SONM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3171a059-104b-4e3e-a38c-8fe95849bfda',
#      'marginable': True,
#      'name': 'Sonos, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SONO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '11574a72-6451-4b65-ae4a-2ede03baac63',
#      'marginable': True,
#      'name': 'Smith & Nephew plc',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e321cf31-5a5c-4b98-be1b-7333cb7439ac',
#      'marginable': True,
#      'name': 'Sonoma Pharmaceuticals, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNOA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '737f100d-b8fe-41a7-b4fe-6d4400f8df04',
#      'marginable': True,
#      'name': 'Xtrackers S&P 500 ESG ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNPE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd982edff-69e4-4261-b596-2b317a4d89f8',
#      'marginable': True,
#      'name': 'NEW SENIOR INVESTMENT GROUP INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '70e6c5b8-a566-4942-93d0-66e0a0324afd',
#      'marginable': True,
#      'name': 'Sunesis Pharmaceuticals, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNSS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c8382768-7d97-42d7-a4a3-f045b9551b7c',
#      'marginable': True,
#      'name': 'Alpha Architect ETF Trust Merlyn.AI Tactical Growth & Income ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNUG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '83be43e4-2663-4e02-b8d4-f7c2dff0e121',
#      'marginable': True,
#      'name': 'Synovus Financial Corp. Fixed-to-Floating Rate Non-Cumulative '
#              'Perpetual Preferred Stock, Series D Li',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNV-D',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '072dffb9-46e5-49b8-93bb-640aa27d4737',
#      'marginable': True,
#      'name': 'Sanofi ADR',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f598a5a7-b813-49de-ba93-b965cbd842d9',
#      'marginable': True,
#      'name': 'Sustainable Opportunities Acquisition Corp.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SOAC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '41cc16c5-60e2-4f43-98f5-78a257ed23c4',
#      'marginable': True,
#      'name': 'Global X Funds Global X Social Media ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOCL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'e4b47d0f-6bcc-4ec6-9a05-44cec5861b4f',
#      'marginable': True,
#      'name': 'Sogou Inc. American Depositary Shares, each representing one '
#              'Class A Ordinary Share',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOGO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '6b6d6ca1-3c70-4f46-8936-54e6cd3dd2ef',
#      'marginable': True,
#      'name': 'Sotherly Hotels Inc. 8.0% Series B Cumulative Redeemable '
#              'Perpetual Preferred Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SOHOB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '03d2037b-b1b5-4724-8459-e08041042cd6',
#      'marginable': True,
#      'name': 'Sotherly Hotels Inc. 7.875% Series C Cumulative Redeemable '
#              'Perpetual Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOHOO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b3eb0612-8710-4a8a-990a-16feb000486b',
#      'marginable': True,
#      'name': 'Solaris Oilfield Infrastructure, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SOI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '9acae523-e2a8-42c6-acaa-0f1ae790dc9c',
#      'marginable': True,
#      'name': 'The Southern Company Series 2016A 5.25% Junior Subordinated Notes '
#              'due October 1, 2076',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOJB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'e935614b-8cb4-4d14-a0a5-980778b40fb4',
#      'marginable': True,
#      'name': 'The Southern Company Series 2020A 4.95% Junior Subordinated Notes '
#              'due January 30, 2080',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOJD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '17e5651c-bbe0-4996-9bdc-2c1d18422c19',
#      'marginable': True,
#      'name': 'Soliton, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOLY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '86c49363-ed29-4f47-a56b-614f36e60bc3',
#      'marginable': True,
#      'name': 'Southern National Bancorp of Virginia, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SONA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9362e926-aafa-47bb-a7e1-b96f1a491b90',
#      'marginable': True,
#      'name': 'Sonnet BioTherapeutics Holdings, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SONN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'dbef6d70-4c4a-4f74-b22b-2fd69ab8d960',
#      'marginable': True,
#      'name': 'Source Capital, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '8bbe960e-89f0-41ce-9f05-0635f26c55ac',
#      'marginable': True,
#      'name': 'Cambria Sovereign Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOVB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '4071ba99-0e64-4998-a7f8-07c114e00ef7',
#      'marginable': True,
#      'name': 'iShares PHLX Semiconductor ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SOXX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '320d4ed2-137d-4b20-ab9f-ac6f8b70e4a1',
#      'marginable': True,
#      'name': 'SP Plus Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '98c6aa57-1a3b-45ee-b8eb-9c72e237c3ba',
#      'marginable': True,
#      'name': 'Spartan Energy Acquisition Corp.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPAQ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b3c01e23-4186-4a75-9c5e-ed1194532671',
#      'marginable': True,
#      'name': 'Spectrum Brands Holdings, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '259c8b5d-39f1-4525-b82a-40545c5b1c33',
#      'marginable': True,
#      'name': 'SuperCom, Ltd. Ordinary Shares (Israel)',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPCB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'd7349556-b7d5-4f99-8667-1cd7252dc5df',
#      'marginable': True,
#      'name': 'AAM S&P 500 High Dividend Value ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPDV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'cc9f2dee-0d13-4f8b-b5ff-ceffa71abd22',
#      'marginable': True,
#      'name': 'Special Opportunities Fund, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '6d6e6232-9219-430d-9eb6-d290ad960615',
#      'marginable': True,
#      'name': 'SPDR Portfolio Emerging Markets ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '24e71cb7-a397-4f85-bd01-4ff70ea4e19a',
#      'marginable': True,
#      'name': 'Global X SuperIncome Preferred ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPFF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'abda5459-cb41-44a7-85bb-c94d32ea7d93',
#      'marginable': True,
#      'name': 'Simon Property Group, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '10f7d07f-0811-42bf-a780-b4d4cb53eb91',
#      'marginable': True,
#      'name': 'S&P Global Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPGI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'a38b51ae-a5a8-4e31-83fc-af5ae2cfdc2f',
#      'marginable': True,
#      'name': 'Invesco S&P 500 GARP ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPGP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'a3d97e99-3368-4b15-b507-f3dcb301ecb4',
#      'marginable': True,
#      'name': 'Invesco S&P 500 High Beta ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPHB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '985215c2-55f7-4f1a-b676-b20d95ddef69',
#      'marginable': True,
#      'name': 'Invesco S&P 500 Quality ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPHQ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'f7b56f4e-1fe0-4242-971b-2a5e88ab66c4',
#      'marginable': True,
#      'name': 'SPDR Portfolio High Yield Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPHY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '41655e39-8fba-4463-a5d1-cd8e5a90d3b6',
#      'marginable': True,
#      'name': 'SPDR Portfolio Intermediate Term Corporate Bond ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPIB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '08ddaecb-04cf-4039-8b28-d9c07ccd5fe6',
#      'marginable': True,
#      'name': 'Spark Energy, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPKE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'de29752c-29ea-479c-8abe-5fca106af9e6',
#      'marginable': True,
#      'name': 'SPDR Portfolio S&P 500 ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPLG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '4f5baf1e-0e9b-4d85-b88a-d874dc4a3c42',
#      'marginable': True,
#      'name': 'VISA Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'V',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'edeb4260-0f85-4e2f-99e3-a71637da43b3',
#      'marginable': True,
#      'name': 'SOS Limited',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '9067979a-40eb-49ef-b8e9-c43fa950e9c7',
#      'marginable': True,
#      'name': 'Direxion Daily Semiconductor Bull 3X Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SOXL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '48ad4a10-f178-42db-9da2-9d0b03251d9f',
#      'marginable': True,
#      'name': 'Direxion Daily Semiconductor Bear 3X Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOXS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '8380bd27-ace5-419c-a691-a09d5237ec9e',
#      'marginable': True,
#      'name': 'Teucrium Soybean Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SOYB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'df6b3ff4-5a79-4f89-91d1-536de2814211',
#      'marginable': True,
#      'name': 'SPDR Portfolio Aggregate Bond ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPAB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'c4a0014d-5630-4870-a5c1-5f36c2e4be04',
#      'marginable': True,
#      'name': 'Spartan Energy Acquisition Corp Units (each consisting of one '
#              'Class A Common Stock and one-third of',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPAQ.U',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '6064be37-fbf7-41d7-8967-1f3adc436733',
#      'marginable': True,
#      'name': 'SPDR Portfolio Corporate Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPBO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '7c7fa08a-c321-46fa-a907-cc7080548f92',
#      'marginable': True,
#      'name': 'Direxion Daily S&P 500 Bear 1X Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPDN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '3d328204-ac8a-4b39-81bc-620e5612041f',
#      'marginable': True,
#      'name': 'SPDR Portfolio Developed World ex-US ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPDW',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'cdac64fe-b5f2-41fb-b207-287f296e0527',
#      'marginable': True,
#      'name': 'Special Opportunities Fund, Inc. 3.50% Convertible Preferred '
#              'Stock, Series B',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPE-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '382fb0ab-d43d-4f32-81a9-10862ad47ef0',
#      'marginable': True,
#      'name': 'SPDR Portfolio Europe ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPEU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '6de683bc-0852-44d1-8d2c-e6faf33282ed',
#      'marginable': True,
#      'name': 'South Plains Financial, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPFI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '2dd22719-ecf6-4ecf-aa49-ae59c8e7999a',
#      'marginable': True,
#      'name': 'Simon Property Group, Inc. 8 3/8% Series J',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPG-J',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'abc3d563-c30f-4db9-84fa-9492a656e35e',
#      'marginable': True,
#      'name': 'SPDR Portfolio MSCI Global Stock Market ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPGM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '58beef20-84ee-4ee7-89f2-2c79b6d0c8d7',
#      'marginable': True,
#      'name': 'Suburban Propane Partners L P',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '95ffb91c-1d4f-4b20-b04a-d8c62f7add51',
#      'marginable': True,
#      'name': 'Invesco S&P 500 High Dividend Low Volatility ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPHD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '420c3bd9-4086-45f1-a95f-978717c57971',
#      'marginable': True,
#      'name': 'SPI Energy Co., Ltd. Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'de645249-28d0-4c20-97f8-49d77deceb46',
#      'marginable': True,
#      'name': 'SPDR Portfolio TIPS ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPIP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c9cb1a81-c602-4ad5-a6fc-30c9edc8c46b',
#      'marginable': True,
#      'name': 'Spark Energy, Inc. 8.75% Series A Fixed-to-Floating Rate '
#              'Cumulative Redeemable Perpetual Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPKEP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '816ceb8c-3c08-4683-823c-d916958fdd79',
#      'marginable': True,
#      'name': 'STEEL PARTNERS HOLDINGS L.P.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPLP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '578e2d24-c969-4608-b6e6-063c3b5e466e',
#      'marginable': True,
#      'name': 'SPDR Portfolio Mortgage Backed Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPMB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '8ffa6cb7-7854-4adf-8243-b953621acb3a',
#      'marginable': True,
#      'name': 'Invesco S&P 500 Momentum ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPMO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '2d7d3c68-0106-4e8b-83dd-ecea7f0c38fb',
#      'marginable': True,
#      'name': 'Superior Energy Services, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7cccc882-ca9c-4cba-996b-b2bc7f8a108a',
#      'marginable': True,
#      'name': 'Sapiens International Corporation N.V. Common Shares (Cayman '
#              'Islands)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPNS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '39a26dc1-927a-4590-b103-b8068a013e7f',
#      'marginable': True,
#      'name': 'Spotify Technology S.A.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPOT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '34f38349-f597-42fd-8e84-da034245a548',
#      'marginable': True,
#      'name': 'Siren ETF Trust Siren Large Cap Blend Index ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPQQ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'f3cf7539-0062-497f-b299-3126fe40019c',
#      'marginable': True,
#      'name': 'Spero Therapeutics, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPRO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '6f8240e9-a8a6-4f3d-95f5-c33b19b10db5',
#      'marginable': True,
#      'name': 'SPDR Portfolio Short Term Corporate Bond ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPSB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'a8047755-f51f-4126-bfec-e738e8d8ae44',
#      'marginable': True,
#      'name': 'SP Funds Dow Jones Global Sukuk ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPSK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'aa8eeae7-e6f7-4951-a7e9-90d9458bb01f',
#      'marginable': True,
#      'name': 'Sprout Social, Inc Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '5199539f-71db-41a2-9d79-5e81d2029e18',
#      'marginable': True,
#      'name': 'SPDR Portfolio Long Term Treasury ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPTL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3196d48f-0ba0-4055-850b-e41ecd1818e0',
#      'marginable': True,
#      'name': 'SpartanNash Company Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPTN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '576a121b-7d1f-4952-9d2a-7540f00013c0',
#      'marginable': True,
#      'name': 'Invesco S&P 500 Value with Momentum ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPVM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3ec017af-f24f-4460-a224-f14385931a4a',
#      'marginable': True,
#      'name': "Sportsman's Warehouse Holdings, Inc. Common Stock",
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPWH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '9efc9dec-d693-4df9-990b-5a619795112f',
#      'marginable': True,
#      'name': 'ProShares S&P 500 Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPXB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'd5fd4368-77c4-4651-a563-7b7620ed6b90',
#      'marginable': True,
#      'name': 'ProShares S&P 500 Ex-Energy ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPXE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '2ae246b0-1a44-4a90-b817-b2ae5bfb5249',
#      'marginable': True,
#      'name': 'ProShares S&P 500 Ex-Technology ETF',
#      'shortable': False,
# ...
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'a666c932-85ed-41ba-a197-1d2a8655bd04',
#      'marginable': True,
#      'name': 'Bausch Health Companies Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BHC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'd4f2e183-f6fa-4187-bb2a-d6bc15956c6f',
#      'marginable': True,
#      'name': 'Brighthouse Financial, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BHF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'ea1cdc7e-1309-488f-af83-1fe8fffae167',
#      'marginable': True,
#      'name': 'Brighthouse Financial, Inc. Depositary Shares 6.75% '
#              'Non-Cumulative Preferred Stock, Series B',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BHFAO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '4ea58c84-7de9-469b-ba4a-228d3a678403',
#      'marginable': True,
#      'name': 'BLACKROCK CORE BD TR',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BHK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '4ac5cb04-cfdb-4670-9637-662f8d08d9f8',
#      'marginable': True,
#      'name': 'BHP Group Limited American Depositary Shares (Each representing '
#              'two Ordinary Shares)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BHP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '7f7f2f23-74f0-4980-85c0-cab6fd60e93c',
#      'marginable': True,
#      'name': 'Braemar Hotels & Resorts Inc. 5.50% Series B Cumulative '
#              'Convertible Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BHR-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '0a956caa-9a87-430b-83d7-348beb2032cf',
#      'marginable': True,
#      'name': 'BioHiTech Global, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BHTG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'a20fbbfe-0082-463a-be06-e790e654925a',
#      'marginable': True,
#      'name': 'Biohaven Pharmaceutical Holding Company Ltd.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BHVN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '9109991f-4132-4326-a50c-5ac7a4fa7d48',
#      'marginable': True,
#      'name': 'Inspire 100 ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BIBL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '0ad668aa-6edf-494a-9220-0f18c3f02e8d',
#      'marginable': True,
#      'name': 'Belden Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BDC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'e14b43f6-2b62-408c-9190-c846d59f697c',
#      'marginable': True,
#      'name': 'ETRACS Quarterly Pay 1.5X  Leveraged Wells Fargo BDC Index ETN',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BDCX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '058bcebe-c908-47e2-80ae-752411d160db',
#      'marginable': True,
#      'name': 'ETRACS Wells Fargo Business Development Company Index ETN Series '
#              'B due April 26, 2041',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BDCZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'a897aae9-f439-43d6-9d6a-4f31a5b0ddde',
#      'marginable': True,
#      'name': 'Innovator S&P 500 Buffer ETF - December',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BDEC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '98f4d6a8-18ba-4fd6-ba10-3bb9f8a3bd69',
#      'marginable': True,
#      'name': 'BlackRock Enhanced Equity Dividend Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BDJ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'cfd6ea36-2ada-4781-a6db-af087cfd5790',
#      'marginable': True,
#      'name': 'Brandywine Realty Trust',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BDN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'c730f4c5-1133-4bb8-a291-42219d6d9914',
#      'marginable': True,
#      'name': 'Breakwave Dry Bulk Shipping ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BDRY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'c1853bd7-f488-4647-8ab4-7ec39ca1ed3c',
#      'marginable': True,
#      'name': 'Black Diamond Therapeutics, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BDTX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '7e17ff71-e2e4-4cbb-9a98-20a998ed766a',
#      'marginable': True,
#      'name': 'Becton, Dickinson and Company Depositary Shares, each '
#              'Representing a 1/20th Interest in a Share of 6',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BDXB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'bf6c1e55-a7ef-4701-9e30-3c43db26b103',
#      'marginable': True,
#      'name': 'Beam Therapeutics Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BEAM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'eae4489c-468a-4d69-9429-0447874ca5ad',
#      'marginable': True,
#      'name': 'Beacon Roofing Supply, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BECN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '288386c3-ac2e-42ff-81be-4f96d180926d',
#      'marginable': True,
#      'name': 'Bel Fuse Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BELFA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '12344127-983c-4142-b3cf-97bc15a8ba70',
#      'marginable': True,
#      'name': 'Franklin Resources, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BEN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '69d0bd9e-1a66-4c39-a200-c0ef67ac4d69',
#      'marginable': True,
#      'name': 'Brookfield Renewable Partners L.P. 5.25% Class A Preferred '
#              'Limited Partnership Units, Series 17',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BEP-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '4e745997-e853-40f5-8cee-3271a3957a20',
#      'marginable': True,
#      'name': 'Berry Global Group, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BERY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'f7cfc3d4-8de5-4fc5-bdd7-67dd0aec3851',
#      'marginable': True,
#      'name': 'Roundhill Sports Betting & iGaming ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BETZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'a7416318-2773-49b9-b843-7017e0711a5b',
#      'marginable': True,
#      'name': 'Brown-Forman Corporation Class B',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BF.B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '9cb847ae-be45-4601-90b7-d1a94561fc4b',
#      'marginable': True,
#      'name': 'Bank First Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BFC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '9e728bb4-326e-4cb4-93b8-e1691df9323e',
#      'marginable': True,
#      'name': 'BankFinancial Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BFIN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '7c8d4369-2c0a-4c12-b586-f50c1e16c3be',
#      'marginable': True,
#      'name': 'BlackRock Municipal Income Trust',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BFK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '8e82ff46-7959-42b7-bc55-b463a5a1bbd0',
#      'marginable': True,
#      'name': 'Biofrontera AG American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BFRA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'a37e5a10-8083-432c-bfb5-dd6013472641',
#      'marginable': True,
#      'name': 'Business First Bancshares, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BFST',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '1f18da2d-2113-49b5-b925-0ec1bee943e9',
#      'marginable': True,
#      'name': 'BLACKROCK CA MUNICIPAL INC TR',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BFZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'bf4fa2a1-e9e7-4d51-a1a7-919c743db93b',
#      'marginable': True,
#      'name': 'BGC Partners, Inc Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BGCP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '707553c3-16a3-4d01-8fa1-a6fc34ad6c23',
#      'marginable': True,
#      'name': 'BlackRock 2022 Global Income Opportunity Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BGIO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'c90d283f-4f76-4b34-aba2-21d028b6ed1f',
#      'marginable': True,
#      'name': 'Blackrock Energy and Resources Trust',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BGR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b86456db-ab89-4135-85c6-45bfa595b85c',
#      'marginable': True,
#      'name': 'B&G Foods, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BGS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '08c5c613-3a75-459c-b87d-108466899813',
#      'marginable': True,
#      'name': 'BlackRock Floating Rate Income Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BGT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '511b9132-ad9b-413e-8ac3-62144e41ad36',
#      'marginable': True,
#      'name': 'BlackRock Enhanced International Dividend Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BGY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '02a6be4e-3245-4a6e-be38-20499e9c9e0e',
#      'marginable': True,
#      'name': 'Biglari Holdings Inc. Class A Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BH.A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': '55b25313-9628-4edf-a0a0-f46d19e03740',
#      'marginable': True,
#      'name': 'Bar Harbor Bankshares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BHB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'a75e07dc-2a4f-40b7-999c-4bb08eedd345',
#      'marginable': True,
#      'name': 'Benchmark Electronics',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BHE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9e689d8e-0275-4a13-a21d-d518b19eb8f2',
#      'marginable': True,
#      'name': 'Brighthouse Financial, Inc. 6.25% Junior Subordinated Debentures '
#              'due 2058',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BHFAL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e6c3faee-7f06-4aee-8b31-610a8e732164',
#      'marginable': True,
#      'name': 'Brighthouse Financial, Inc. Depositary Shares 6.6% Non-Cumulative '
#              'Preferred Stock, Series A',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BHFAP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '09d13f10-3e93-45ba-b6db-31e1a2e8d59e',
#      'marginable': True,
#      'name': 'Berkshire Hills Bancorp, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BHLB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'c59097fb-6c78-4f2b-9927-b80a37bb22ef',
#      'marginable': True,
#      'name': 'Braemar Hotels & Resorts Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BHR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '832ad7b3-07ef-4f2d-80c3-f32c1a146824',
#      'marginable': True,
#      'name': 'Braemar Hotels & Resorts Inc. 8.25% Series D Cumulative Preferred '
#              'Stock, par value $0.01 per share',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BHR-D',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '1454ca6b-44a6-4d5a-a4b3-5f4f052eb626',
#      'marginable': True,
#      'name': 'BlackRock Virginia Muni Bond Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BHV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '03e4b300-1dc7-4842-9385-3afc411cbf1b',
#      'marginable': True,
#      'name': 'ProShares Trust ProShares Ultra Nasdaq Biotechnology',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BIB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'd4a03a6c-3df4-476f-9ff5-cee722c8a3ff',
#      'marginable': True,
#      'name': 'First Trust Exchange-Traded Fund II First Trust BICK Index Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BICK',
#      'tradable': True}),
#  ...]
